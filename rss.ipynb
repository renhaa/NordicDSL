# %%
import feedparser
#!pip3 install feedparser
cms = "https://timesofindia.indiatimes.com/rssfeedstopstories.cms"
cms = "https://www.dr.dk/nyheder/service/feeds/allenyheder"
feedparser = feedparser.parse(cms)
entries = NewsFeed.entries

feedparser.entries
# Out:
# [{'id': '78e0b975-b918-4932-a61d-c5d6143e09bc',
#   'guidislink': False,
#   'title': 'De er isolerede, flygter og spiser ikke: Nu skal millionbeløb tage toppen af ensomheden hos folk med handicap',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.dr.dk/nyheder/service/feeds/allenyheder',
#    'value': 'De er isolerede, flygter og spiser ikke: Nu skal millionbeløb tage toppen af ensomheden hos folk med handicap'},
#   'summary': 'Regeringen vil give ti millioner til Danske Handicaporganisationer, der skal hjælpe folk tilbage mod hverdagen.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.dr.dk/nyheder/service/feeds/allenyheder',
#    'value': 'Regeringen vil give ti millioner til Danske Handicaporganisationer, der skal hjælpe folk tilbage mod hverdagen.'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
# ...
